# %%
from os.path import join
from praatio import tgio
import praatio
from pydub import AudioSegment
import pandas as pd
import os
import re

# %%
print("\n------> Loading directories and files... ------\n")
source_dir = '/srv/scratch/chacmod/checked'
print(f'.wav files and TextGrid files are stored at: {source_dir}')

save_dir = '/srv/scratch/chacmod/auskidtalk_scripted_audio_new'
print(f'Split .wav files are stored at: {save_dir}')

save_df_fp = '/srv/scratch/z5313567/thesis/AusKidTalk_local/scripted_new/AusKidTalk_scripted_dataframe_new_175_speakers.csv'
print(f'Dataframe file is stored at: {save_df_fp}')
# Out:
# ------> Loading directories and files... ------
#
# .wav files and TextGrid files are stored at: /srv/scratch/chacmod/checked
# Split .wav files are stored at: /srv/scratch/chacmod/auskidtalk_scripted_audio_new
# Dataframe file is stored at: /srv/scratch/z5313567/thesis/AusKidTalk_local/scripted_new/AusKidTalk_scripted_dataframe_new_175_speakers.csv

# %%
extracted_audio = []
extracted_transcription = []
extracted_speakerID = []
extracted_filepath = []
extracted_duration = []

# %%
for root, dirs, files in os.walk(source_dir):
    for filename in files:
        if filename.endswith('.wav'):
            wav_filepath = os.path.join(root, filename)
            speaker_id = os.path.basename(root)
            textgrid_filename = speaker_id + "_task1_kaldi" + '.TextGrid'
            textgrid_filepath = os.path.join(root, textgrid_filename)
            if not os.path.exists(textgrid_filepath): # if the TextGrid file with the name convention speakerID_task1_kaldi.TextGrid does not exist
                textgrid_filename = speaker_id + "_task1_GT" + '.TextGrid'
                textgrid_filepath = os.path.join(root, textgrid_filename)
                if not os.path.exists(textgrid_filepath):
                    continue  # if the TextGrid file with the name convention speakerID_task1_GT.TextGrid does not exist
            
            # extracting speeches from TextGrid files
            audio = AudioSegment.from_wav(wav_filepath)
            try:
                tg = tgio.openTextgrid(textgrid_filepath)
            except AssertionError:
                print("AssertionError occurred:")
                print(f"The TextGrid file is {textgrid_filepath} \n")
            tier_names = tg.tierNameList
            
            print('Currently Processing:')
            print('TextGrid File:', textgrid_filepath)
            print('Tier names:', tier_names)
            print('\n')
            
            count = 1
            for xmin, xmax, text in tg.tierDict[tier_names[2]].entryList:
                if text != 'sil':
                    split_audio = audio[xmin*1000:xmax*1000] # the unit is in milliseconds
                    save_filepath = os.path.join(save_dir, speaker_id+'_'+str(count)+'.wav')
                    split_audio.export(save_filepath, format='wav')

                    chars_to_ignore = '[\,\?\.\!\-\;\_\:\"]'
                    text = re.sub(chars_to_ignore, ' ', text).lower()

                    extracted_audio.append(split_audio)
                    extracted_transcription.append(text)
                    extracted_speakerID.append(speaker_id)
                    extracted_filepath.append(save_filepath)
                    extracted_duration.append(xmax-xmin)

                    count = count+1
# Out:
# Currently Processing:
# TextGrid File: /srv/scratch/chacmod/checked/439/439_task1_kaldi.TextGrid
# Tier names: ['Prompt', 'speaker_1-kaldi-words', 'hu-wrd', 'flag']
#
#
# Currently Processing:
# TextGrid File: /srv/scratch/chacmod/checked/637/637_task1_kaldi.TextGrid
# Tier names: ['Prompt', 'speaker_2-kaldi-words', 'hu-wrd', 'flag']
#
#
# Currently Processing:
# TextGrid File: /srv/scratch/chacmod/checked/457/457_task1_kaldi.TextGrid
# Tier names: ['Prompt', 'speaker_2-kaldi-words', 'hu-wrd', 'flag']
#
#
# Currently Processing:
# TextGrid File: /srv/scratch/chacmod/checked/772/772_task1_kaldi.TextGrid
# Tier names: ['Prompt', 'speaker_0-kaldi-words', 'hu-wrd', 'flag']
#
#
# Currently Processing:
# TextGrid File: /srv/scratch/chacmod/checked/655/655_task1_kaldi.TextGrid
# Tier names: ['Prompt', 'speaker_0-kaldi-words', 'hu-wrd', 'flag']
#
#
# Currently Processing:
# TextGrid File: /srv/scratch/chacmod/checked/970/970_task1_kaldi.TextGrid
# Tier names: ['Prompt', 'speaker_2-kaldi-words', 'hu-wrd', 'flag']
#
#
# Currently Processing:
# TextGrid File: /srv/scratch/chacmod/checked/682/682_task1_kaldi.TextGrid
# Tier names: ['Prompt', 'speaker_1-kaldi-words', 'hu-wrd', 'flag']
#
#
# Currently Processing:
# TextGrid File: /srv/scratch/chacmod/checked/547/547_task1_kaldi.TextGrid
# Tier names: ['Prompt', 'speaker_0-kaldi-words', 'hu-wrd', 'flag']
#
#
# Currently Processing:
# TextGrid File: /srv/scratch/chacmod/checked/466/466_task1_kaldi.TextGrid
# Tier names: ['Prompt', 'speaker_1-kaldi-words', 'hu-wrd', 'flag']
#
#
# Anomaly: startTime=81.004000, stopTime=81.004000, label=tooth
# AssertionError occurred:
# The TextGrid file is /srv/scratch/chacmod/checked/781/781_task1_kaldi.TextGrid
#
# Currently Processing:
# TextGrid File: /srv/scratch/chacmod/checked/781/781_task1_kaldi.TextGrid
# Tier names: ['Prompt', 'speaker_1-kaldi-words', 'hu-wrd', 'flag']
#
#
# Currently Processing:
# TextGrid File: /srv/scratch/chacmod/checked/943/943_task1_kaldi.TextGrid
# Tier names: ['Prompt', 'speaker_1-kaldi-words', 'hu-wrd', 'flag']
#
#
# Currently Processing:
# TextGrid File: /srv/scratch/chacmod/checked/349/349_task1_kaldi.TextGrid
# Tier names: ['Prompt', 'speaker-1', 'hu-wrd', 'flag']
#
#
# Currently Processing:
# TextGrid File: /srv/scratch/chacmod/checked/97/97_task1_kaldi.TextGrid
# Tier names: ['Prompt', 'speaker-1', 'hu-wrd', 'flag']
#
#
# Currently Processing:
# TextGrid File: /srv/scratch/chacmod/checked/978/978_task1_kaldi.TextGrid
# Tier names: ['Prompt', 'speaker_1-kaldi-words', 'hu-wrd', 'flag']
#
#
# Currently Processing:
# TextGrid File: /srv/scratch/chacmod/checked/897/897_task1_kaldi.TextGrid
# Tier names: ['Prompt', 'speaker_1-kaldi-words', 'hu-wrd', 'flag']
#
#
# Currently Processing:
# TextGrid File: /srv/scratch/chacmod/checked/440/440_task1_kaldi.TextGrid
# Tier names: ['Prompt', 'speaker_0-kaldi-words', 'hu-wrd', 'flag']
#
#
# Currently Processing:
# TextGrid File: /srv/scratch/chacmod/checked/323/323_task1_kaldi.TextGrid
# Tier names: ['Prompt', 'speaker-1', 'hu-wrd', 'flag']
#
#
# Currently Processing:
# TextGrid File: /srv/scratch/chacmod/checked/620/620_task1_kaldi.TextGrid
# Tier names: ['Prompt', 'speaker_1-kaldi-words', 'hu-wrd', 'flag']
#
#
# Currently Processing:
# TextGrid File: /srv/scratch/chacmod/checked/260/260_task1_kaldi.TextGrid
# Tier names: ['Prompt', 'speaker-1', 'hu-wrd', 'flag']
#
#
# Currently Processing:
# TextGrid File: /srv/scratch/chacmod/checked/413/413_task1_kaldi.TextGrid
# Tier names: ['Prompt', 'speaker-1', 'hu-wrd', 'flag']
#
#
# Currently Processing:
# TextGrid File: /srv/scratch/chacmod/checked/251/251_task1_kaldi.TextGrid
# Tier names: ['Prompt', 'speaker-0', 'hu-wrd', 'flag']
#
#
# Currently Processing:
# TextGrid File: /srv/scratch/chacmod/checked/431/431_task1_kaldi.TextGrid
# Tier names: ['Prompt', 'speaker-1', 'hu-wrd', 'flag']
#
#
# Currently Processing:
# TextGrid File: /srv/scratch/chacmod/checked/776/776_task1_kaldi.TextGrid
# Tier names: ['Prompt', 'speaker_0-kaldi-words', 'hu-wrd', 'flag']
#
#
# Currently Processing:
# TextGrid File: /srv/scratch/chacmod/checked/857/857_task1_kaldi.TextGrid
# Tier names: ['Prompt', 'speaker_1-kaldi-words', 'hu-wrd', 'flag']
#
#
# Currently Processing:
# TextGrid File: /srv/scratch/chacmod/checked/884/884_task1_kaldi.TextGrid
# Tier names: ['Prompt', 'speaker_1-kaldi-words', 'hu-wrd', 'flag']
#
#
# Currently Processing:
# TextGrid File: /srv/scratch/chacmod/checked/389/389_task1_kaldi.TextGrid
# Tier names: ['Prompt', 'speaker-1', 'hu-wrd', 'flag']
#
#
# Currently Processing:
# TextGrid File: /srv/scratch/chacmod/checked/785/785_task1_kaldi.TextGrid
# Tier names: ['Prompt', 'speaker_1-kaldi-words', 'hu-wrd', 'flag']
#
#
# Currently Processing:
# TextGrid File: /srv/scratch/chacmod/checked/749/749_task1_kaldi.TextGrid
# Tier names: ['Prompt', 'speaker_1-kaldi-words', 'hu-wrd', 'flag']
#
#
# Currently Processing:
# TextGrid File: /srv/scratch/chacmod/checked/220/220_task1_kaldi.TextGrid
# Tier names: ['Prompt', 'speaker-1', 'hu-wrd', 'flag']
#
#
# Currently Processing:
# TextGrid File: /srv/scratch/chacmod/checked/301/301_task1_kaldi.TextGrid
# Tier names: ['Prompt', 'speaker-1', 'hu-wrd', 'flag']
#
#
# Currently Processing:
# TextGrid File: /srv/scratch/chacmod/checked/211/211_task1_kaldi.TextGrid
# Tier names: ['Prompt', 'speaker-0', 'hu-wrd', 'flag']
#
#
# Currently Processing:
# TextGrid File: /srv/scratch/chacmod/checked/130/130_task1_kaldi.TextGrid
# Tier names: ['Prompt', 'speaker-0', 'hu-wrd', 'flag']
#
#
# Currently Processing:
# TextGrid File: /srv/scratch/chacmod/checked/310/310_task1_kaldi.TextGrid
# Tier names: ['Prompt', 'speaker-1', 'hu-wrd', 'flag']
#
#
# Currently Processing:
# TextGrid File: /srv/scratch/chacmod/checked/1524/1524_task1_GT.TextGrid
# Tier names: ['Prompt', 'Nemo-sp-1', 'Final-wrd', 'Final-flag-nemo']
#
#
# Currently Processing:
# TextGrid File: /srv/scratch/chacmod/checked/444/444_task1_kaldi.TextGrid
# Tier names: ['Prompt', 'speaker_1-kaldi-words', 'hu-wrd', 'flag']
#
#
# Currently Processing:
# TextGrid File: /srv/scratch/chacmod/checked/282/282_task1_kaldi.TextGrid
# Tier names: ['Prompt', 'speaker-1', 'hu-wrd', 'flag']
#
#
# Currently Processing:
# TextGrid File: /srv/scratch/chacmod/checked/408/408_task1_kaldi.TextGrid
# Tier names: ['Prompt', 'speaker-1', 'hu-wrd', 'flag']
#
#
# Currently Processing:
# TextGrid File: /srv/scratch/chacmod/checked/246/246_task1_kaldi.TextGrid
# Tier names: ['Prompt', 'speaker-1', 'hu-wrd', 'flag']
#
#
# Currently Processing:
# TextGrid File: /srv/scratch/chacmod/checked/228/228_task1_kaldi.TextGrid
# Tier names: ['Prompt', 'speaker_0-kaldi-words', 'hu-wrd', 'flag']
#
#
# Currently Processing:
# TextGrid File: /srv/scratch/chacmod/checked/264/264_task1_kaldi.TextGrid
# Tier names: ['Prompt', 'speaker-1', 'hu-wrd', 'flag']
#
#
# Currently Processing:
# TextGrid File: /srv/scratch/chacmod/checked/219/219_task1_kaldi.TextGrid
# Tier names: ['Prompt', 'speaker-1', 'hu-wrd', 'flag']
#
#
# Currently Processing:
# TextGrid File: /srv/scratch/chacmod/checked/651/651_task1_kaldi.TextGrid
# Tier names: ['Prompt', 'speaker-0', 'hu-wrd', 'flag']
#
#
# Currently Processing:
# TextGrid File: /srv/scratch/chacmod/checked/255/255_task1_kaldi.TextGrid
# Tier names: ['Prompt', 'speaker-0', 'hu-wrd', 'flag']
#
#
# Currently Processing:
# TextGrid File: /srv/scratch/chacmod/checked/714/714_task1_kaldi.TextGrid
# Tier names: ['Prompt', 'speaker_0-kaldi-words', 'hu-wrd', 'flag']
#
#
# Currently Processing:
# TextGrid File: /srv/scratch/chacmod/checked/237/237_task1_kaldi.TextGrid
# Tier names: ['Prompt', 'speaker-1', 'hu-wrd', 'flag']
#
#
# Currently Processing:
# TextGrid File: /srv/scratch/chacmod/checked/318/318_task1_kaldi.TextGrid
# Tier names: ['Prompt', 'speaker-1', 'hu-wrd', 'flag']
#
#
# Currently Processing:
# TextGrid File: /srv/scratch/chacmod/checked/516/516_task1_kaldi.TextGrid
# Tier names: ['Prompt', 'speaker-1', 'hu-wrd', 'flag']
#
#
# Currently Processing:
# TextGrid File: /srv/scratch/chacmod/checked/396/396_task1_kaldi.TextGrid
# Tier names: ['Prompt', 'speaker-0', 'hu-wrd', 'flag']
#
#
# Currently Processing:
# TextGrid File: /srv/scratch/chacmod/checked/477/477_task1_kaldi.TextGrid
# Tier names: ['Prompt', 'speaker_2-kaldi-words', 'hu-wrd', 'flag']
#
#
# Currently Processing:
# TextGrid File: /srv/scratch/chacmod/checked/954/954_task1_kaldi.TextGrid
# Tier names: ['Prompt', 'speaker_0-kaldi-words', 'hu-wrd', 'flag']
#
#
# Currently Processing:
# TextGrid File: /srv/scratch/chacmod/checked/378/378_task1_kaldi.TextGrid
# Tier names: ['Prompt', 'speaker-1', 'hu-wrd', 'flag']
#
#
# Currently Processing:
# TextGrid File: /srv/scratch/chacmod/checked/459/459_task1_kaldi.TextGrid
# Tier names: ['Prompt', 'speaker_0-kaldi-words', 'hu-wrd', 'flag']
#
#
# Currently Processing:
# TextGrid File: /srv/scratch/chacmod/checked/774/774_task1_kaldi.TextGrid
# Tier names: ['Prompt', 'speaker_1-kaldi-words', 'hu-wrd', 'flag']
#
#
# Currently Processing:
# TextGrid File: /srv/scratch/chacmod/checked/819/819_task1_kaldi.TextGrid
# Tier names: ['Prompt', 'speaker-0', 'hu-wrd', 'flag']
#
#
# Currently Processing:
# TextGrid File: /srv/scratch/chacmod/checked/972/972_task1_kaldi.TextGrid
# Tier names: ['Prompt', 'speaker_2-kaldi-words', 'hu-wrd', 'flag']
#
#
# Currently Processing:
# TextGrid File: /srv/scratch/chacmod/checked/1001/1001_task1_kaldi.TextGrid
# Tier names: ['Prompt', 'speaker_0-kaldi-words', 'hu-wrd', 'flag']
#
#
# Currently Processing:
# TextGrid File: /srv/scratch/chacmod/checked/729/729_task1_kaldi.TextGrid
# Tier names: ['Prompt', 'speaker_1-kaldi-words', 'hu-wrd', 'flag']
#
#
# Currently Processing:
# TextGrid File: /srv/scratch/chacmod/checked/882/882_task1_kaldi.TextGrid
# Tier names: ['Prompt', 'speaker_2-kaldi-words', 'hu-wrd', 'flag']
#
#
# Currently Processing:
# TextGrid File: /srv/scratch/chacmod/checked/864/864_task1_kaldi.TextGrid
# Tier names: ['Prompt', 'speaker_0-kaldi-words', 'hu-wrd', 'flag']
#
#
# Currently Processing:
# TextGrid File: /srv/scratch/chacmod/checked/899/899_task1_kaldi.TextGrid
# Tier names: ['Prompt', 'speaker_3-kaldi-words', 'hu-wrd', 'flag']
#
#
# Currently Processing:
# TextGrid File: /srv/scratch/chacmod/checked/1423/1423_task1_kaldi.TextGrid
# Tier names: ['Prompt', 'speaker_0-kaldi-words', 'hu-wrd', 'flag']
#
#
# Currently Processing:
# TextGrid File: /srv/scratch/chacmod/checked/208/208_task1_kaldi.TextGrid
# Tier names: ['Prompt', 'speaker-1', 'hu-wrd', 'flag']
#
#
# Currently Processing:
# TextGrid File: /srv/scratch/chacmod/checked/406/406_task1_kaldi.TextGrid
# Tier names: ['Prompt', 'speaker-1', 'hu-wrd', 'flag']
#
#
# Currently Processing:
# TextGrid File: /srv/scratch/chacmod/checked/325/325_task1_kaldi.TextGrid
# Tier names: ['Prompt', 'speaker-1', 'hu-wrd', 'flag']
#
#
# Currently Processing:
# TextGrid File: /srv/scratch/chacmod/checked/460/460_task1_kaldi.TextGrid
# Tier names: ['Prompt', 'speaker_2-kaldi-words', 'hu-wrd', 'flag']
#
#
# Currently Processing:
# TextGrid File: /srv/scratch/chacmod/checked/307/307_task1_kaldi.TextGrid
# Tier names: ['Prompt', 'speaker-1', 'hu-wrd', 'flag']
#
#
# Currently Processing:
# TextGrid File: /srv/scratch/chacmod/checked/343/343_task1_kaldi.TextGrid
# Tier names: ['Prompt', 'speaker-1', 'hu-wrd', 'flag']
#
#
# Currently Processing:
# TextGrid File: /srv/scratch/chacmod/checked/451/451_task1_kaldi.TextGrid
# Tier names: ['Prompt', 'speaker_0-kaldi-words', 'hu-wrd', 'flag']
#
#
# Currently Processing:
# TextGrid File: /srv/scratch/chacmod/checked/172/172_task1_kaldi.TextGrid
# Tier names: ['Prompt', 'speaker-0', 'hu-wrd', 'flag']
#
#
# Currently Processing:
# TextGrid File: /srv/scratch/chacmod/checked/316/316_task1_kaldi.TextGrid
# Tier names: ['Prompt', 'speaker-1', 'hu-wrd', 'flag']
#
#
# Currently Processing:
# TextGrid File: /srv/scratch/chacmod/checked/118/118_task1_kaldi.TextGrid
# Tier names: ['Prompt', 'speaker-0', 'hu-wrd', 'flag']
#
#
# Currently Processing:
# TextGrid File: /srv/scratch/chacmod/checked/352/352_task1_kaldi.TextGrid
# Tier names: ['Prompt', 'speaker-1', 'hu-wrd', 'flag']
#
#
# Currently Processing:
# TextGrid File: /srv/scratch/chacmod/checked/1032/1032_task1_kaldi.TextGrid
# Tier names: ['Prompt', 'speaker_0-kaldi-words', 'hu-wrd', 'flag']
#
#
# Currently Processing:
# TextGrid File: /srv/scratch/chacmod/checked/1050/1050_task1_kaldi.TextGrid
# Tier names: ['Prompt', 'speaker_0-kaldi-words', 'hu-wrd', 'flag']
#
#
# Currently Processing:
# TextGrid File: /srv/scratch/chacmod/checked/967/967_task1_kaldi.TextGrid
# Tier names: ['Prompt', 'speaker_0-kaldi-words', 'hu-wrd', 'flag']
#
#
# Currently Processing:
# TextGrid File: /srv/scratch/chacmod/checked/321/321_task1_kaldi.TextGrid
# Tier names: ['Prompt', 'speaker-0', 'hu-wrd', 'flag']
#
#
# Currently Processing:
# TextGrid File: /srv/scratch/chacmod/checked/222/222_task1_kaldi.TextGrid
# Tier names: ['Prompt', 'speaker-0', 'hu-wrd', 'flag']
#
#
# Currently Processing:
# TextGrid File: /srv/scratch/chacmod/checked/303/303_task1_kaldi.TextGrid
# Tier names: ['Prompt', 'speaker-1', 'hu-wrd', 'flag']
#
#
# Currently Processing:
# TextGrid File: /srv/scratch/chacmod/checked/842/842_task1_kaldi.TextGrid
# Tier names: ['Prompt', 'speaker_0-kaldi-words', 'hu-wrd', 'flag']
#
#
# Currently Processing:
# TextGrid File: /srv/scratch/chacmod/checked/680/680_task1_kaldi.TextGrid
# Tier names: ['Prompt', 'speaker-0', 'hu-wrd', 'flag']
#
#
# Currently Processing:
# TextGrid File: /srv/scratch/chacmod/checked/545/545_task1_kaldi.TextGrid
# Tier names: ['Prompt', 'speaker_2-kaldi-words', 'hu-wrd', 'flag']
#
#
# Currently Processing:
# TextGrid File: /srv/scratch/chacmod/checked/941/941_task1_kaldi.TextGrid
# Tier names: ['Prompt', 'speaker_1-kaldi-words', 'hu-wrd', 'flag']
#
#
# Currently Processing:
# TextGrid File: /srv/scratch/chacmod/checked/743/743_task1_kaldi.TextGrid
# Tier names: ['Prompt', 'speaker_0-kaldi-words', 'hu-wrd', 'flag']
#
#
# Currently Processing:
# TextGrid File: /srv/scratch/chacmod/checked/266/266_task1_kaldi.TextGrid
# Tier names: ['Prompt', 'speaker-2', 'hu-wrd', 'flag']
#
#
# Currently Processing:
# TextGrid File: /srv/scratch/chacmod/checked/536/536_task1_kaldi.TextGrid
# Tier names: ['Prompt', 'speaker_0-kaldi-words', 'hu-wrd', 'flag']
#
#
# Currently Processing:
# TextGrid File: /srv/scratch/chacmod/checked/770/770_task1_kaldi.TextGrid
# Tier names: ['Prompt', 'speaker_2-kaldi-words', 'hu-wrd', 'flag']
#
#
# Currently Processing:
# TextGrid File: /srv/scratch/chacmod/checked/653/653_task1_kaldi.TextGrid
# Tier names: ['Prompt', 'speaker_0-kaldi-words', 'hu-wrd', 'flag']
#
#
# Currently Processing:
# TextGrid File: /srv/scratch/chacmod/checked/176/176_task1_kaldi.TextGrid
# Tier names: ['Prompt', 'speaker-2', 'hu-wrd', 'flag']
#
#
# Currently Processing:
# TextGrid File: /srv/scratch/chacmod/checked/752/752_task1_kaldi.TextGrid
# Tier names: ['Prompt', 'speaker_0-kaldi-words', 'hu-wrd', 'flag']
#
#
# Currently Processing:
# TextGrid File: /srv/scratch/chacmod/checked/671/671_task1_kaldi.TextGrid
# Tier names: ['Prompt', 'speaker_2-kaldi-words', 'hu-wrd', 'flag']
#
#
# Currently Processing:
# TextGrid File: /srv/scratch/chacmod/checked/197/197_task1_kaldi.TextGrid
# Tier names: ['Prompt', 'speaker-0', 'hu-wrd', 'flag']
#
#
# Currently Processing:
# TextGrid File: /srv/scratch/chacmod/checked/719/719_task1_kaldi.TextGrid
# Tier names: ['Prompt', 'speaker-0', 'hu-wrd', 'flag']
#
#
# Currently Processing:
# TextGrid File: /srv/scratch/chacmod/checked/872/872_task1_kaldi.TextGrid
# Tier names: ['Prompt', 'speaker_0-kaldi-words', 'hu-wrd', 'flag']
#
#
# Currently Processing:
# TextGrid File: /srv/scratch/chacmod/checked/377/377_task1_kaldi.TextGrid
# Tier names: ['Prompt', 'speaker-1', 'hu-wrd', 'flag']
#
#
# Currently Processing:
# TextGrid File: /srv/scratch/chacmod/checked/539/539_task1_kaldi.TextGrid
# Tier names: ['Prompt', 'speaker_0-kaldi-words', 'hu-wrd', 'flag']
#
#
# Currently Processing:
# TextGrid File: /srv/scratch/chacmod/checked/818/818_task1_kaldi.TextGrid
# Tier names: ['Prompt', 'speaker_2-kaldi-words', 'hu-wrd', 'flag']
#
#
# Currently Processing:
# TextGrid File: /srv/scratch/chacmod/checked/1000/1000_task1_kaldi.TextGrid
# Tier names: ['Prompt', 'speaker_0-kaldi-words', 'hu-wrd', 'flag']
#
#
# Currently Processing:
# TextGrid File: /srv/scratch/chacmod/checked/485/485_task1_kaldi.TextGrid
# Tier names: ['Prompt', 'speaker_2-kaldi-words', 'hu-wrd', 'flag']
#
#
# Currently Processing:
# TextGrid File: /srv/scratch/chacmod/checked/782/782_task1_kaldi.TextGrid
# Tier names: ['Prompt', 'speaker_0-kaldi-words', 'hu-wrd', 'flag']
#
#
# Currently Processing:
# TextGrid File: /srv/scratch/chacmod/checked/898/898_task1_kaldi.TextGrid
# Tier names: ['Prompt', 'speaker_0-kaldi-words', 'hu-wrd', 'flag']
#
#
# Currently Processing:
# TextGrid File: /srv/scratch/chacmod/checked/603/603_task1_kaldi.TextGrid
# Tier names: ['Prompt', 'speaker_1-kaldi-words', 'hu-wrd', 'flag']
#
#
# Currently Processing:
# TextGrid File: /srv/scratch/chacmod/checked/243/243_task1_kaldi.TextGrid
# Tier names: ['Prompt', 'speaker-1', 'hu-wrd', 'flag']
#
#
# Currently Processing:
# TextGrid File: /srv/scratch/chacmod/checked/342/342_task1_kaldi.TextGrid
# Tier names: ['Prompt', 'speaker-1', 'hu-wrd', 'flag']
#
#
# Currently Processing:
# TextGrid File: /srv/scratch/chacmod/checked/216/216_task1_kaldi.TextGrid
# Tier names: ['Prompt', 'speaker-1', 'hu-wrd', 'flag']
#
#
# Currently Processing:
# TextGrid File: /srv/scratch/chacmod/checked/135/135_task1_kaldi.TextGrid
# Tier names: ['Prompt', 'speaker-1', 'hu-wrd', 'flag']
#
#
# Currently Processing:
# TextGrid File: /srv/scratch/chacmod/checked/270/270_task1_kaldi.TextGrid
# Tier names: ['Prompt', 'speaker-1', 'hu-wrd', 'flag']
#
#
# Currently Processing:
# TextGrid File: /srv/scratch/chacmod/checked/351/351_task1_kaldi.TextGrid
# Tier names: ['Prompt', 'speaker-1', 'hu-wrd', 'flag']
#
#
# Currently Processing:
# TextGrid File: /srv/scratch/chacmod/checked/678/678_task1_kaldi.TextGrid
# Tier names: ['Prompt', 'speaker_1-kaldi-words', 'hu-wrd', 'flag']
#
#
# Currently Processing:
# TextGrid File: /srv/scratch/chacmod/checked/777/777_task1_kaldi.TextGrid
# Tier names: ['Prompt', 'speaker_1-kaldi-words', 'hu-wrd', 'flag']
#
#
# Currently Processing:
# TextGrid File: /srv/scratch/chacmod/checked/498/498_task1_kaldi.TextGrid
# Tier names: ['Prompt', 'speaker_1-kaldi-words', 'hu-wrd', 'flag']
#
#
# Currently Processing:
# TextGrid File: /srv/scratch/chacmod/checked/975/975_task1_kaldi.TextGrid
# Tier names: ['Prompt', 'speaker_2-kaldi-words', 'hu-wrd', 'flag']
#
#
# Currently Processing:
# TextGrid File: /srv/scratch/chacmod/checked/885/885_task1_kaldi.TextGrid
# Tier names: ['Prompt', 'speaker_0-kaldi-words', 'hu-wrd', 'flag']
#
#
# Currently Processing:
# TextGrid File: /srv/scratch/chacmod/checked/203/203_task1_kaldi.TextGrid
# Tier names: ['Prompt', 'speaker-0', 'hu-wrd', 'flag']
#
#
# Currently Processing:
# TextGrid File: /srv/scratch/chacmod/checked/122/122_task1_kaldi.TextGrid
# Tier names: ['Prompt', 'speaker-1', 'hu-wrd', 'flag']
#
#
# Currently Processing:
# TextGrid File: /srv/scratch/chacmod/checked/320/320_task1_kaldi.TextGrid
# Tier names: ['Prompt', 'speaker-0', 'hu-wrd', 'flag']
#
#
# Currently Processing:
# TextGrid File: /srv/scratch/chacmod/checked/221/221_task1_kaldi.TextGrid
# Tier names: ['Prompt', 'speaker-1', 'hu-wrd', 'flag']
#
#
# Currently Processing:
# TextGrid File: /srv/scratch/chacmod/checked/302/302_task1_kaldi.TextGrid
# Tier names: ['Prompt', 'speaker-1', 'hu-wrd', 'flag']
#
#
# Currently Processing:
# TextGrid File: /srv/scratch/chacmod/checked/230/230_task1_kaldi.TextGrid
# Tier names: ['Prompt', 'speaker-1', 'hu-wrd', 'flag']
#
#
# Currently Processing:
# TextGrid File: /srv/scratch/chacmod/checked/1075/1075_task1_kaldi.TextGrid
# Tier names: ['Prompt', 'speaker-1', 'hu-wrd', 'flag']
#
#
# Currently Processing:
# TextGrid File: /srv/scratch/chacmod/checked/445/445_task1_kaldi.TextGrid
# Tier names: ['Prompt', 'speaker_2-kaldi-words', 'hu-wrd', 'flag']
#
#
# Currently Processing:
# TextGrid File: /srv/scratch/chacmod/checked/841/841_task1_kaldi.TextGrid
# Tier names: ['Prompt', 'speaker_1-kaldi-words', 'hu-wrd', 'flag']
#
#
# Currently Processing:
# TextGrid File: /srv/scratch/chacmod/checked/409/409_task1_kaldi.TextGrid
# Tier names: ['Prompt', 'speaker-1', 'hu-wrd', 'flag']
#
#
# Currently Processing:
# TextGrid File: /srv/scratch/chacmod/checked/166/166_task1_kaldi.TextGrid
# Tier names: ['Prompt', 'speaker-0', 'hu-wrd', 'flag']
#
#
# Currently Processing:
# TextGrid File: /srv/scratch/chacmod/checked/328/328_task1_kaldi.TextGrid
# Tier names: ['Prompt', 'speaker-1', 'hu-wrd', 'flag']
#
#
# Currently Processing:
# TextGrid File: /srv/scratch/chacmod/checked/544/544_task1_kaldi.TextGrid
# Tier names: ['Prompt', 'speaker_0-kaldi-words', 'hu-wrd', 'flag']
#
#
# Currently Processing:
# TextGrid File: /srv/scratch/chacmod/checked/229/229_task1_kaldi.TextGrid
# Tier names: ['Prompt', 'speaker-1', 'hu-wrd', 'flag']
#
#
# Currently Processing:
# TextGrid File: /srv/scratch/chacmod/checked/346/346_task1_kaldi.TextGrid
# Tier names: ['Prompt', 'speaker-1', 'hu-wrd', 'flag']
#
#
# Currently Processing:
# TextGrid File: /srv/scratch/chacmod/checked/490/490_task1_kaldi.TextGrid
# Tier names: ['Prompt', 'speaker_0-kaldi-words', 'hu-wrd', 'flag']
#
#
# Currently Processing:
# TextGrid File: /srv/scratch/chacmod/checked/715/715_task1_kaldi.TextGrid
# Tier names: ['Prompt', 'speaker_1-kaldi-words', 'hu-wrd', 'flag']
#
#
# Currently Processing:
# TextGrid File: /srv/scratch/chacmod/checked/472/472_task1_kaldi.TextGrid
# Tier names: ['Prompt', 'speaker_1-kaldi-words', 'hu-wrd', 'flag']
#
#
# Currently Processing:
# TextGrid File: /srv/scratch/chacmod/checked/193/193_task1_kaldi.TextGrid
# Tier names: ['Prompt', 'speaker-1', 'hu-wrd', 'flag']
#
#
# Currently Processing:
# TextGrid File: /srv/scratch/chacmod/checked/955/955_task1_kaldi.TextGrid
# Tier names: ['Prompt', 'speaker_0-kaldi-words', 'hu-wrd', 'flag']
#
#
# Currently Processing:
# TextGrid File: /srv/scratch/chacmod/checked/379/379_task1_kaldi.TextGrid
# Tier names: ['Prompt', 'speaker-1', 'hu-wrd', 'flag']
#
#
# Currently Processing:
# TextGrid File: /srv/scratch/chacmod/checked/694/694_task1_kaldi.TextGrid
# Tier names: ['Prompt', 'speaker_0-kaldi-words', 'hu-wrd', 'flag']
#
#
# Currently Processing:
# TextGrid File: /srv/scratch/chacmod/checked/739/739_task1_kaldi.TextGrid
# Tier names: ['Prompt', 'speaker_2-kaldi-words', 'hu-wrd', 'flag']
#
#
# Currently Processing:
# TextGrid File: /srv/scratch/chacmod/checked/973/973_task1_kaldi.TextGrid
# Tier names: ['Prompt', 'speaker_2-kaldi-words', 'hu-wrd', 'flag']
#
#
# Currently Processing:
# TextGrid File: /srv/scratch/chacmod/checked/289/289_task1_kaldi.TextGrid
# Tier names: ['Prompt', 'speaker-1', 'hu-wrd', 'flag']
#
#
# Currently Processing:
# TextGrid File: /srv/scratch/chacmod/checked/748/748_task1_kaldi.TextGrid
# Tier names: ['Prompt', 'speaker_0-kaldi-words', 'hu-wrd', 'flag']
#
#
# Currently Processing:
# TextGrid File: /srv/scratch/chacmod/checked/667/667_task1_kaldi.TextGrid
# Tier names: ['Prompt', 'speaker_1-kaldi-words', 'hu-wrd', 'flag']
#
#
# Currently Processing:
# TextGrid File: /srv/scratch/chacmod/checked/982/982_task1_kaldi.TextGrid
# Tier names: ['Prompt', 'speaker_3-kaldi-words', 'hu-wrd', 'flag']
#
#
# Currently Processing:
# TextGrid File: /srv/scratch/chacmod/checked/605/605_task1_kaldi.TextGrid
# Tier names: ['Prompt', 'speaker_1-kaldi-words', 'hu-wrd', 'flag']
#
#
# Currently Processing:
# TextGrid File: /srv/scratch/chacmod/checked/407/407_task1_kaldi.TextGrid
# Tier names: ['Prompt', 'speaker-1', 'hu-wrd', 'flag']
#
#
# Currently Processing:
# TextGrid File: /srv/scratch/chacmod/checked/326/326_task1_kaldi.TextGrid
# Tier names: ['Prompt', 'speaker-1', 'hu-wrd', 'flag']
#
#
# Currently Processing:
# TextGrid File: /srv/scratch/chacmod/checked/542/542_task1_kaldi.TextGrid
# Tier names: ['Prompt', 'speaker_1-kaldi-words', 'hu-wrd', 'flag']
#
#
# Currently Processing:
# TextGrid File: /srv/scratch/chacmod/checked/461/461_task1_kaldi.TextGrid
# Tier names: ['Prompt', 'speaker_2-kaldi-words', 'hu-wrd', 'flag']
#
#
# Currently Processing:
# TextGrid File: /srv/scratch/chacmod/checked/263/263_task1_kaldi.TextGrid
# Tier names: ['Prompt', 'speaker-1', 'hu-wrd', 'flag']
#
#
# Currently Processing:
# TextGrid File: /srv/scratch/chacmod/checked/218/218_task1_kaldi.TextGrid
# Tier names: ['Prompt', 'speaker-1', 'hu-wrd', 'flag']
#
#
# Currently Processing:
# TextGrid File: /srv/scratch/chacmod/checked/470/470_task1_kaldi.TextGrid
# Tier names: ['Prompt', 'speaker_0-kaldi-words', 'hu-wrd', 'flag']
#
#
# Currently Processing:
# TextGrid File: /srv/scratch/chacmod/checked/632/632_task1_kaldi.TextGrid
# Tier names: ['Prompt', 'speaker_2-kaldi-words', 'hu-wrd', 'flag']
#
#
# Currently Processing:
# TextGrid File: /srv/scratch/chacmod/checked/434/434_task1_kaldi.TextGrid
# Tier names: ['Prompt', 'speaker_1-kaldi-words', 'hu-wrd', 'flag']
#
#
# Currently Processing:
# TextGrid File: /srv/scratch/chacmod/checked/272/272_task1_kaldi.TextGrid
# Tier names: ['Prompt', 'speaker-1', 'hu-wrd', 'flag']
#
#
# Currently Processing:
# TextGrid File: /srv/scratch/chacmod/checked/191/191_task1_kaldi.TextGrid
# Tier names: ['Prompt', 'speaker-1', 'hu-wrd', 'flag']
#
#
# Currently Processing:
# TextGrid File: /srv/scratch/chacmod/checked/353/353_task1_kaldi.TextGrid
# Tier names: ['Prompt', 'speaker-1', 'hu-wrd', 'flag']
#
#
# Currently Processing:
# TextGrid File: /srv/scratch/chacmod/checked/1150/1150_task1_kaldi.TextGrid
# Tier names: ['Prompt', 'speaker-1', 'hu-wrd', 'flag']
#
#
# Currently Processing:
# TextGrid File: /srv/scratch/chacmod/checked/977/977_task1_kaldi.TextGrid
# Tier names: ['Prompt', 'speaker_2-kaldi-words', 'hu-wrd', 'flag']
#
#
# Currently Processing:
# TextGrid File: /srv/scratch/chacmod/checked/896/896_task1_kaldi.TextGrid
# Tier names: ['Prompt', 'speaker_1-kaldi-words', 'hu-wrd', 'flag']
#
#
# Currently Processing:
# TextGrid File: /srv/scratch/chacmod/checked/1303/1303_task1_kaldi.TextGrid
# Tier names: ['Prompt', 'speaker_0-kaldi-words', 'hu-wrd', 'flag']
#
#
# Currently Processing:
# TextGrid File: /srv/scratch/chacmod/checked/205/205_task1_kaldi.TextGrid
# Tier names: ['Prompt', 'speaker-1', 'hu-wrd', 'flag']
#
#
# Currently Processing:
# TextGrid File: /srv/scratch/chacmod/checked/322/322_task1_kaldi.TextGrid
# Tier names: ['Prompt', 'speaker-1', 'hu-wrd', 'flag']
#
#
# Currently Processing:
# TextGrid File: /srv/scratch/chacmod/checked/304/304_task1_kaldi.TextGrid
# Tier names: ['Prompt', 'speaker-1', 'hu-wrd', 'flag']
#
#
# Currently Processing:
# TextGrid File: /srv/scratch/chacmod/checked/502/502_task1_kaldi.TextGrid
# Tier names: ['Prompt', 'speaker_0-kaldi-words', 'hu-wrd', 'flag']
#
#
# Currently Processing:
# TextGrid File: /srv/scratch/chacmod/checked/250/250_task1_kaldi.TextGrid
# Tier names: ['Prompt', 'speaker-1', 'hu-wrd', 'flag']
#
#
# Currently Processing:
# TextGrid File: /srv/scratch/chacmod/checked/232/232_task1_kaldi.TextGrid
# Tier names: ['Prompt', 'speaker-1', 'hu-wrd', 'flag']
#
#
# Currently Processing:
# TextGrid File: /srv/scratch/chacmod/checked/313/313_task1_kaldi.TextGrid
# Tier names: ['Prompt', 'speaker-0', 'hu-wrd', 'flag']
#
#
# Currently Processing:
# TextGrid File: /srv/scratch/chacmod/checked/430/430_task1_kaldi.TextGrid
# Tier names: ['Prompt', 'speaker-0', 'hu-wrd', 'flag']
#
#
# Currently Processing:
# TextGrid File: /srv/scratch/chacmod/checked/1464/1464_task1_GT.TextGrid
# Tier names: ['Prompt', 'Nemo-sp-0', 'Final-wrd', 'Final-flag-nemo']
#
#
# Currently Processing:
# TextGrid File: /srv/scratch/chacmod/checked/447/447_task1_kaldi.TextGrid
# Tier names: ['Prompt', 'speaker_1-kaldi-words', 'hu-wrd', 'flag']
#
#
# Currently Processing:
# TextGrid File: /srv/scratch/chacmod/checked/681/681_task1_kaldi.TextGrid
# Tier names: ['Prompt', 'speaker_0-kaldi-words', 'hu-wrd', 'flag']
#
#
# Currently Processing:
# TextGrid File: /srv/scratch/chacmod/checked/465/465_task1_kaldi.TextGrid
# Tier names: ['Prompt', 'speaker_2-kaldi-words', 'hu-wrd', 'flag']
#
#
# Currently Processing:
# TextGrid File: /srv/scratch/chacmod/checked/429/429_task1_kaldi.TextGrid
# Tier names: ['Prompt', 'speaker-0', 'hu-wrd', 'flag']
#
#
# Currently Processing:
# TextGrid File: /srv/scratch/chacmod/checked/456/456_task1_kaldi.TextGrid
# Tier names: ['Prompt', 'speaker_1-kaldi-words', 'hu-wrd', 'flag']
#
#
# Currently Processing:
# TextGrid File: /srv/scratch/chacmod/checked/339/339_task1_kaldi.TextGrid
# Tier names: ['Prompt', 'speaker-0', 'hu-wrd', 'flag']
#
#
# Currently Processing:
# TextGrid File: /srv/scratch/chacmod/checked/393/393_task1_kaldi.TextGrid
# Tier names: ['Prompt', 'speaker-1', 'hu-wrd', 'flag']
#
#
# Currently Processing:
# TextGrid File: /srv/scratch/chacmod/checked/474/474_task1_kaldi.TextGrid
# Tier names: ['Prompt', 'speaker_1-kaldi-words', 'hu-wrd', 'flag']
#
#
# Currently Processing:
# TextGrid File: /srv/scratch/chacmod/checked/672/672_task1_kaldi.TextGrid
# Tier names: ['Prompt', 'speaker_0-kaldi-words', 'hu-wrd', 'flag']

# %%
print(len(extracted_filepath))
print(len(extracted_duration))
print(len(extracted_speakerID))
print(len(extracted_transcription))
# Out:
# 25687
# 25687
# 25687
# 25687

# %%
print("\n------> Generating dataframe ... ------\n")
df = pd.DataFrame(
        {'filepath': extracted_filepath,
         'duration': extracted_duration,
         'speaker_id': extracted_speakerID,
         'transcription': extracted_transcription,
         })
# preverse leading zeros
df['speaker_id'] = df['speaker_id'].astype(str) 

print("\n------> Saving dataframe to csv file... ------\n")
df.to_csv(save_df_fp, index=False)
print('Successfully saved dataframe to csv file at: ', save_df_fp)
print("Total number of speakers:", len(set(extracted_speakerID)))
print("Total hours:", df['duration'].sum()/(60*60))
# Out:
# ------> Generating dataframe ... ------
#
#
# ------> Saving dataframe to csv file... ------
#
# Successfully saved dataframe to csv file at:  /srv/scratch/z5313567/thesis/AusKidTalk_local/scripted_new/AusKidTalk_scripted_dataframe_new_175_speakers.csv
# Total number of speakers: 175
# Total hours: 5.406107334492203
