# %%
from IPython.display import Audio
import librosa

# %%
audio_path = '/srv/scratch/speechdata/speech-corpora/AusTalk/speakers/speakers/1_1119/sentences/1_1119_2_16_009-ch6-speaker16.wav'
audio = Audio(audio_path)
display(audio)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
audio_path = '/srv/scratch/chacmod/auskidtalk_spontaneous/1075_10.wav'
audio = Audio(audio_path)
display(audio)

y, sr = librosa.load(audio_path)

# Print the sampling rate
print(f"Sampling rate: {sr} Hz")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Sampling rate: 22050 Hz

# %%
audio_path = '/srv/scratch/speechdata/speech-corpora/AusTalk/speakers/speakers/1_222/sentences/1_222_2_16_059-ch6-speaker16.wav'
audio = Audio(audio_path)
display(audio)

y, sr = librosa.load(audio_path)

# Print the sampling rate
print(f"Sampling rate: {sr} Hz")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Sampling rate: 22050 Hz
